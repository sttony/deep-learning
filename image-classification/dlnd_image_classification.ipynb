# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 3
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 3:
# Image - Min Value: 4 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    r = x /255.0
    return r


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    l = len(x)
    r = np.zeros((l, 10))
    for i in range(l):
        r[i][x[i]] =1 
    return r


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    input = tf.placeholder(
        tf.float32,
        shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')
    return input


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    input = tf.placeholder(
        tf.float32,
        shape=[None, n_classes], name='y')
    return input


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep= tf.placeholder(tf.float32, name='keep_prob')
    return keep


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    image_width = x_tensor.get_shape().as_list()[2]
    image_height = x_tensor.get_shape().as_list()[1]
    color_channels = x_tensor.get_shape().as_list()[3]
    conv_height = conv_ksize[1]
    conv_width = conv_ksize[0]
    
   
    weight = tf.Variable(tf.truncated_normal(
        [conv_height, conv_width, color_channels, conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_layer = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
        
    
    conv_layer = tf.nn.max_pool(conv_layer, ksize=[1, pool_ksize[0], pool_ksize[1], 1]
                                , strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')

    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    flattenedSize= x_tensor.get_shape().as_list()[1] \
                   *x_tensor.get_shape().as_list()[2] \
                   *x_tensor.get_shape().as_list()[3]
    
    
    layer = tf.reshape( x_tensor, [-1, flattenedSize])
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    input_size = x_tensor.shape.as_list()[1]
    weight = tf.Variable(tf.truncated_normal(
        [input_size, num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    layer_1 = tf.nn.relu(x_tensor)
    layer_1 = tf.add(tf.matmul(layer_1, weight), bias)
    
    return layer_1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    input_size = x_tensor.shape.as_list()[1]
    weight = tf.Variable(tf.truncated_normal(
        [input_size, num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    layer_1 = tf.add(tf.matmul(x_tensor, weight), bias)
    
    return layer_1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    num_outputs = 10 
    conv_num_outputs  = 24
    conv_ksize = (2, 2)
    conv_strides = (2, 2)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    x_tensor = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x_tensor = flatten(x_tensor)
    x_tensor = tf.nn.dropout(x_tensor, keep_prob)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x_tensor = fully_conn(x_tensor, num_outputs)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x_tensor = output(x_tensor, num_outputs)
    
    # TODO: return output
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob:keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    current_cost = session.run(
        cost,
        feed_dict={x: feature_batch, y: label_batch, keep_prob:1.0})
    valid_accuracy = session.run(
        accuracy,
        feed_dict={x: valid_features, y: valid_labels,keep_prob:1.0})
    print('Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        current_cost,
        valid_accuracy))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 59.2     Valid Accuracy: 0.122
# Epoch  2, CIFAR-10 Batch 1:  Cost: 40.4     Valid Accuracy: 0.135
# Epoch  3, CIFAR-10 Batch 1:  Cost: 28.9     Valid Accuracy: 0.147
# Epoch  4, CIFAR-10 Batch 1:  Cost: 22.7     Valid Accuracy: 0.161
# Epoch  5, CIFAR-10 Batch 1:  Cost: 17.6     Valid Accuracy: 0.165
# Epoch  6, CIFAR-10 Batch 1:  Cost: 13.8     Valid Accuracy: 0.173
# Epoch  7, CIFAR-10 Batch 1:  Cost: 9.53     Valid Accuracy: 0.172
# Epoch  8, CIFAR-10 Batch 1:  Cost: 6.47     Valid Accuracy: 0.174
# Epoch  9, CIFAR-10 Batch 1:  Cost: 4.76     Valid Accuracy: 0.169
# Epoch 10, CIFAR-10 Batch 1:  Cost: 3.57     Valid Accuracy: 0.16
# Epoch 11, CIFAR-10 Batch 1:  Cost: 3.21     Valid Accuracy: 0.157
# Epoch 12, CIFAR-10 Batch 1:  Cost: 3.09     Valid Accuracy: 0.154
# Epoch 13, CIFAR-10 Batch 1:  Cost: 2.99     Valid Accuracy: 0.147
# Epoch 14, CIFAR-10 Batch 1:  Cost: 2.82     Valid Accuracy: 0.143
# Epoch 15, CIFAR-10 Batch 1:  Cost: 2.71     Valid Accuracy: 0.137
# Epoch 16, CIFAR-10 Batch 1:  Cost: 2.6      Valid Accuracy: 0.135
# Epoch 17, CIFAR-10 Batch 1:  Cost: 2.53     Valid Accuracy: 0.132
# Epoch 18, CIFAR-10 Batch 1:  Cost: 2.46     Valid Accuracy: 0.128
# Epoch 19, CIFAR-10 Batch 1:  Cost: 2.4      Valid Accuracy: 0.132
# Epoch 20, CIFAR-10 Batch 1:  Cost: 2.34     Valid Accuracy: 0.129
# Epoch 21, CIFAR-10 Batch 1:  Cost: 2.3      Valid Accuracy: 0.129
# Epoch 22, CIFAR-10 Batch 1:  Cost: 2.25     Valid Accuracy: 0.129
# Epoch 23, CIFAR-10 Batch 1:  Cost: 2.21     Valid Accuracy: 0.13
# Epoch 24, CIFAR-10 Batch 1:  Cost: 2.17     Valid Accuracy: 0.131
# Epoch 25, CIFAR-10 Batch 1:  Cost: 2.14     Valid Accuracy: 0.132
# Epoch 26, CIFAR-10 Batch 1:  Cost: 2.12     Valid Accuracy: 0.151
# Epoch 27, CIFAR-10 Batch 1:  Cost: 2.1      Valid Accuracy: 0.152
# Epoch 28, CIFAR-10 Batch 1:  Cost: 2.08     Valid Accuracy: 0.152
# Epoch 29, CIFAR-10 Batch 1:  Cost: 2.07     Valid Accuracy: 0.151
# Epoch 30, CIFAR-10 Batch 1:  Cost: 2.06     Valid Accuracy: 0.152
# Epoch 31, CIFAR-10 Batch 1:  Cost: 2.05     Valid Accuracy: 0.15
# Epoch 32, CIFAR-10 Batch 1:  Cost: 2.04     Valid Accuracy: 0.153
# Epoch 33, CIFAR-10 Batch 1:  Cost: 2.04     Valid Accuracy: 0.153
# Epoch 34, CIFAR-10 Batch 1:  Cost: 2.04     Valid Accuracy: 0.155
# Epoch 35, CIFAR-10 Batch 1:  Cost: 2.03     Valid Accuracy: 0.154
# Epoch 36, CIFAR-10 Batch 1:  Cost: 2.03     Valid Accuracy: 0.157
# Epoch 37, CIFAR-10 Batch 1:  Cost: 2.02     Valid Accuracy: 0.161
# Epoch 38, CIFAR-10 Batch 1:  Cost: 2.02     Valid Accuracy: 0.16
# Epoch 39, CIFAR-10 Batch 1:  Cost: 2.02     Valid Accuracy: 0.162
# Epoch 40, CIFAR-10 Batch 1:  Cost: 2.02     Valid Accuracy: 0.171
# Epoch 41, CIFAR-10 Batch 1:  Cost: 2.02     Valid Accuracy: 0.171
# Epoch 42, CIFAR-10 Batch 1:  Cost: 2.01     Valid Accuracy: 0.171
# Epoch 43, CIFAR-10 Batch 1:  Cost: 2.01     Valid Accuracy: 0.173
# Epoch 44, CIFAR-10 Batch 1:  Cost: 2.01     Valid Accuracy: 0.175
# Epoch 45, CIFAR-10 Batch 1:  Cost: 2.0      Valid Accuracy: 0.176
# Epoch 46, CIFAR-10 Batch 1:  Cost: 2.0      Valid Accuracy: 0.176
# Epoch 47, CIFAR-10 Batch 1:  Cost: 1.99     Valid Accuracy: 0.177
# Epoch 48, CIFAR-10 Batch 1:  Cost: 1.99     Valid Accuracy: 0.18
# Epoch 49, CIFAR-10 Batch 1:  Cost: 1.98     Valid Accuracy: 0.185
# Epoch 50, CIFAR-10 Batch 1:  Cost: 1.97     Valid Accuracy: 0.185
# Epoch 51, CIFAR-10 Batch 1:  Cost: 1.96     Valid Accuracy: 0.19
# Epoch 52, CIFAR-10 Batch 1:  Cost: 1.96     Valid Accuracy: 0.19
# Epoch 53, CIFAR-10 Batch 1:  Cost: 1.95     Valid Accuracy: 0.191
# Epoch 54, CIFAR-10 Batch 1:  Cost: 1.94     Valid Accuracy: 0.197
# Epoch 55, CIFAR-10 Batch 1:  Cost: 1.94     Valid Accuracy: 0.196
# Epoch 56, CIFAR-10 Batch 1:  Cost: 1.93     Valid Accuracy: 0.199
# Epoch 57, CIFAR-10 Batch 1:  Cost: 1.92     Valid Accuracy: 0.204
# Epoch 58, CIFAR-10 Batch 1:  Cost: 1.9      Valid Accuracy: 0.208
# Epoch 59, CIFAR-10 Batch 1:  Cost: 1.9      Valid Accuracy: 0.21
# Epoch 60, CIFAR-10 Batch 1:  Cost: 1.9      Valid Accuracy: 0.212
# Epoch 61, CIFAR-10 Batch 1:  Cost: 1.89     Valid Accuracy: 0.217
# Epoch 62, CIFAR-10 Batch 1:  Cost: 1.89     Valid Accuracy: 0.22
# Epoch 63, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.225
# Epoch 64, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.226
# Epoch 65, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.228
# Epoch 66, CIFAR-10 Batch 1:  Cost: 1.86     Valid Accuracy: 0.232
# Epoch 67, CIFAR-10 Batch 1:  Cost: 1.86     Valid Accuracy: 0.235
# Epoch 68, CIFAR-10 Batch 1:  Cost: 1.86     Valid Accuracy: 0.239
# Epoch 69, CIFAR-10 Batch 1:  Cost: 1.86     Valid Accuracy: 0.244
# Epoch 70, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.247
# Epoch 71, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.252
# Epoch 72, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.256
# Epoch 73, CIFAR-10 Batch 1:  Cost: 1.89     Valid Accuracy: 0.262
# Epoch 74, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.262
# Epoch 75, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.268
# Epoch 76, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.27
# Epoch 77, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.273
# Epoch 78, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.279
# Epoch 79, CIFAR-10 Batch 1:  Cost: 1.88     Valid Accuracy: 0.282
# Epoch 80, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.283
# Epoch 81, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.286
# Epoch 82, CIFAR-10 Batch 1:  Cost: 1.86     Valid Accuracy: 0.295
# Epoch 83, CIFAR-10 Batch 1:  Cost: 1.85     Valid Accuracy: 0.295
# Epoch 84, CIFAR-10 Batch 1:  Cost: 1.85     Valid Accuracy: 0.307
# Epoch 85, CIFAR-10 Batch 1:  Cost: 1.84     Valid Accuracy: 0.306
# Epoch 86, CIFAR-10 Batch 1:  Cost: 1.83     Valid Accuracy: 0.317
# Epoch 87, CIFAR-10 Batch 1:  Cost: 1.84     Valid Accuracy: 0.324
# Epoch 88, CIFAR-10 Batch 1:  Cost: 1.82     Valid Accuracy: 0.33
# Epoch 89, CIFAR-10 Batch 1:  Cost: 1.82     Valid Accuracy: 0.336
# Epoch 90, CIFAR-10 Batch 1:  Cost: 1.82     Valid Accuracy: 0.336
# Epoch 91, CIFAR-10 Batch 1:  Cost: 1.8      Valid Accuracy: 0.336
# Epoch 92, CIFAR-10 Batch 1:  Cost: 1.8      Valid Accuracy: 0.34
# Epoch 93, CIFAR-10 Batch 1:  Cost: 1.78     Valid Accuracy: 0.341
# Epoch 94, CIFAR-10 Batch 1:  Cost: 1.79     Valid Accuracy: 0.343
# Epoch 95, CIFAR-10 Batch 1:  Cost: 1.77     Valid Accuracy: 0.345
# Epoch 96, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.349
# Epoch 97, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.353
# Epoch 98, CIFAR-10 Batch 1:  Cost: 1.74     Valid Accuracy: 0.351
# Epoch 99, CIFAR-10 Batch 1:  Cost: 1.74     Valid Accuracy: 0.355
# Epoch 100, CIFAR-10 Batch 1:  Cost: 1.72     Valid Accuracy: 0.361

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 43.7     Valid Accuracy: 0.105
# Epoch  1, CIFAR-10 Batch 2:  Cost: 44.1     Valid Accuracy: 0.117
# Epoch  1, CIFAR-10 Batch 3:  Cost: 26.8     Valid Accuracy: 0.126
# Epoch  1, CIFAR-10 Batch 4:  Cost: 21.7     Valid Accuracy: 0.147
# Epoch  1, CIFAR-10 Batch 5:  Cost: 13.8     Valid Accuracy: 0.165
# Epoch  2, CIFAR-10 Batch 1:  Cost: 14.6     Valid Accuracy: 0.18
# Epoch  2, CIFAR-10 Batch 2:  Cost: 13.0     Valid Accuracy: 0.19
# Epoch  2, CIFAR-10 Batch 3:  Cost: 8.02     Valid Accuracy: 0.193
# Epoch  2, CIFAR-10 Batch 4:  Cost: 6.82     Valid Accuracy: 0.192
# Epoch  2, CIFAR-10 Batch 5:  Cost: 4.69     Valid Accuracy: 0.191
# Epoch  3, CIFAR-10 Batch 1:  Cost: 3.51     Valid Accuracy: 0.175
# Epoch  3, CIFAR-10 Batch 2:  Cost: 3.19     Valid Accuracy: 0.155
# Epoch  3, CIFAR-10 Batch 3:  Cost: 2.49     Valid Accuracy: 0.14
# Epoch  3, CIFAR-10 Batch 4:  Cost: 2.61     Valid Accuracy: 0.139
# Epoch  3, CIFAR-10 Batch 5:  Cost: 2.72     Valid Accuracy: 0.132
# Epoch  4, CIFAR-10 Batch 1:  Cost: 2.48     Valid Accuracy: 0.137
# Epoch  4, CIFAR-10 Batch 2:  Cost: 2.56     Valid Accuracy: 0.135
# Epoch  4, CIFAR-10 Batch 3:  Cost: 2.4      Valid Accuracy: 0.122
# Epoch  4, CIFAR-10 Batch 4:  Cost: 2.38     Valid Accuracy: 0.138
# Epoch  4, CIFAR-10 Batch 5:  Cost: 2.45     Valid Accuracy: 0.118
# Epoch  5, CIFAR-10 Batch 1:  Cost: 2.4      Valid Accuracy: 0.132
# Epoch  5, CIFAR-10 Batch 2:  Cost: 2.38     Valid Accuracy: 0.114
# Epoch  5, CIFAR-10 Batch 3:  Cost: 2.41     Valid Accuracy: 0.113
# Epoch  5, CIFAR-10 Batch 4:  Cost: 2.32     Valid Accuracy: 0.128
# Epoch  5, CIFAR-10 Batch 5:  Cost: 2.35     Valid Accuracy: 0.109
# Epoch  6, CIFAR-10 Batch 1:  Cost: 2.35     Valid Accuracy: 0.108
# Epoch  6, CIFAR-10 Batch 2:  Cost: 2.35     Valid Accuracy: 0.127
# Epoch  6, CIFAR-10 Batch 3:  Cost: 2.39     Valid Accuracy: 0.108
# Epoch  6, CIFAR-10 Batch 4:  Cost: 2.29     Valid Accuracy: 0.127
# Epoch  6, CIFAR-10 Batch 5:  Cost: 2.3      Valid Accuracy: 0.107
# Epoch  7, CIFAR-10 Batch 1:  Cost: 2.32     Valid Accuracy: 0.127
# Epoch  7, CIFAR-10 Batch 2:  Cost: 2.32     Valid Accuracy: 0.128
# Epoch  7, CIFAR-10 Batch 3:  Cost: 2.37     Valid Accuracy: 0.108
# Epoch  7, CIFAR-10 Batch 4:  Cost: 2.28     Valid Accuracy: 0.123
# Epoch  7, CIFAR-10 Batch 5:  Cost: 2.27     Valid Accuracy: 0.106
# Epoch  8, CIFAR-10 Batch 1:  Cost: 2.29     Valid Accuracy: 0.124
# Epoch  8, CIFAR-10 Batch 2:  Cost: 2.3      Valid Accuracy: 0.125
# Epoch  8, CIFAR-10 Batch 3:  Cost: 2.34     Valid Accuracy: 0.12
# Epoch  8, CIFAR-10 Batch 4:  Cost: 2.27     Valid Accuracy: 0.122
# Epoch  8, CIFAR-10 Batch 5:  Cost: 2.25     Valid Accuracy: 0.115
# Epoch  9, CIFAR-10 Batch 1:  Cost: 2.27     Valid Accuracy: 0.123
# Epoch  9, CIFAR-10 Batch 2:  Cost: 2.29     Valid Accuracy: 0.124
# Epoch  9, CIFAR-10 Batch 3:  Cost: 2.33     Valid Accuracy: 0.122
# Epoch  9, CIFAR-10 Batch 4:  Cost: 2.26     Valid Accuracy: 0.124
# Epoch  9, CIFAR-10 Batch 5:  Cost: 2.26     Valid Accuracy: 0.118
# Epoch 10, CIFAR-10 Batch 1:  Cost: 2.25     Valid Accuracy: 0.126
# Epoch 10, CIFAR-10 Batch 2:  Cost: 2.26     Valid Accuracy: 0.125
# Epoch 10, CIFAR-10 Batch 3:  Cost: 2.32     Valid Accuracy: 0.125
# Epoch 10, CIFAR-10 Batch 4:  Cost: 2.24     Valid Accuracy: 0.124
# Epoch 10, CIFAR-10 Batch 5:  Cost: 2.26     Valid Accuracy: 0.117
# Epoch 11, CIFAR-10 Batch 1:  Cost: 2.22     Valid Accuracy: 0.125
# Epoch 11, CIFAR-10 Batch 2:  Cost: 2.23     Valid Accuracy: 0.128
# Epoch 11, CIFAR-10 Batch 3:  Cost: 2.31     Valid Accuracy: 0.126
# Epoch 11, CIFAR-10 Batch 4:  Cost: 2.23     Valid Accuracy: 0.125
# Epoch 11, CIFAR-10 Batch 5:  Cost: 2.27     Valid Accuracy: 0.118
# Epoch 12, CIFAR-10 Batch 1:  Cost: 2.21     Valid Accuracy: 0.125
# Epoch 12, CIFAR-10 Batch 2:  Cost: 2.21     Valid Accuracy: 0.132
# Epoch 12, CIFAR-10 Batch 3:  Cost: 2.3      Valid Accuracy: 0.129
# Epoch 12, CIFAR-10 Batch 4:  Cost: 2.21     Valid Accuracy: 0.129
# Epoch 12, CIFAR-10 Batch 5:  Cost: 2.27     Valid Accuracy: 0.133
# Epoch 13, CIFAR-10 Batch 1:  Cost: 2.21     Valid Accuracy: 0.131
# Epoch 13, CIFAR-10 Batch 2:  Cost: 2.21     Valid Accuracy: 0.131
# Epoch 13, CIFAR-10 Batch 3:  Cost: 2.29     Valid Accuracy: 0.136
# Epoch 13, CIFAR-10 Batch 4:  Cost: 2.16     Valid Accuracy: 0.136
# Epoch 13, CIFAR-10 Batch 5:  Cost: 2.27     Valid Accuracy: 0.138
# Epoch 14, CIFAR-10 Batch 1:  Cost: 2.21     Valid Accuracy: 0.14
# Epoch 14, CIFAR-10 Batch 2:  Cost: 2.23     Valid Accuracy: 0.14
# Epoch 14, CIFAR-10 Batch 3:  Cost: 2.29     Valid Accuracy: 0.145
# Epoch 14, CIFAR-10 Batch 4:  Cost: 2.12     Valid Accuracy: 0.145
# Epoch 14, CIFAR-10 Batch 5:  Cost: 2.29     Valid Accuracy: 0.148
# Epoch 15, CIFAR-10 Batch 1:  Cost: 2.2      Valid Accuracy: 0.154
# Epoch 15, CIFAR-10 Batch 2:  Cost: 2.2      Valid Accuracy: 0.157
# Epoch 15, CIFAR-10 Batch 3:  Cost: 2.29     Valid Accuracy: 0.157
# Epoch 15, CIFAR-10 Batch 4:  Cost: 2.09     Valid Accuracy: 0.164
# Epoch 15, CIFAR-10 Batch 5:  Cost: 2.3      Valid Accuracy: 0.162
# Epoch 16, CIFAR-10 Batch 1:  Cost: 2.23     Valid Accuracy: 0.166
# Epoch 16, CIFAR-10 Batch 2:  Cost: 2.14     Valid Accuracy: 0.165
# Epoch 16, CIFAR-10 Batch 3:  Cost: 2.29     Valid Accuracy: 0.172
# Epoch 16, CIFAR-10 Batch 4:  Cost: 2.07     Valid Accuracy: 0.174
# Epoch 16, CIFAR-10 Batch 5:  Cost: 2.31     Valid Accuracy: 0.181
# Epoch 17, CIFAR-10 Batch 1:  Cost: 2.25     Valid Accuracy: 0.178
# Epoch 17, CIFAR-10 Batch 2:  Cost: 2.09     Valid Accuracy: 0.176
# Epoch 17, CIFAR-10 Batch 3:  Cost: 2.24     Valid Accuracy: 0.186
# Epoch 17, CIFAR-10 Batch 4:  Cost: 2.07     Valid Accuracy: 0.183
# Epoch 17, CIFAR-10 Batch 5:  Cost: 2.29     Valid Accuracy: 0.189
# Epoch 18, CIFAR-10 Batch 1:  Cost: 2.23     Valid Accuracy: 0.201
# Epoch 18, CIFAR-10 Batch 2:  Cost: 2.05     Valid Accuracy: 0.199
# Epoch 18, CIFAR-10 Batch 3:  Cost: 2.19     Valid Accuracy: 0.203
# Epoch 18, CIFAR-10 Batch 4:  Cost: 2.07     Valid Accuracy: 0.205
# Epoch 18, CIFAR-10 Batch 5:  Cost: 2.26     Valid Accuracy: 0.207
# Epoch 19, CIFAR-10 Batch 1:  Cost: 2.18     Valid Accuracy: 0.213
# Epoch 19, CIFAR-10 Batch 2:  Cost: 2.04     Valid Accuracy: 0.215
# Epoch 19, CIFAR-10 Batch 3:  Cost: 2.11     Valid Accuracy: 0.218
# Epoch 19, CIFAR-10 Batch 4:  Cost: 2.08     Valid Accuracy: 0.224
# Epoch 19, CIFAR-10 Batch 5:  Cost: 2.19     Valid Accuracy: 0.224
# Epoch 20, CIFAR-10 Batch 1:  Cost: 2.08     Valid Accuracy: 0.239
# Epoch 20, CIFAR-10 Batch 2:  Cost: 2.06     Valid Accuracy: 0.24
# Epoch 20, CIFAR-10 Batch 3:  Cost: 2.05     Valid Accuracy: 0.249
# Epoch 20, CIFAR-10 Batch 4:  Cost: 2.08     Valid Accuracy: 0.241
# Epoch 20, CIFAR-10 Batch 5:  Cost: 2.13     Valid Accuracy: 0.242
# Epoch 21, CIFAR-10 Batch 1:  Cost: 2.0      Valid Accuracy: 0.258
# Epoch 21, CIFAR-10 Batch 2:  Cost: 2.03     Valid Accuracy: 0.261
# Epoch 21, CIFAR-10 Batch 3:  Cost: 1.94     Valid Accuracy: 0.273
# Epoch 21, CIFAR-10 Batch 4:  Cost: 2.1      Valid Accuracy: 0.277
# Epoch 21, CIFAR-10 Batch 5:  Cost: 1.99     Valid Accuracy: 0.281
# Epoch 22, CIFAR-10 Batch 1:  Cost: 1.94     Valid Accuracy: 0.299
# Epoch 22, CIFAR-10 Batch 2:  Cost: 2.03     Valid Accuracy: 0.299
# Epoch 22, CIFAR-10 Batch 3:  Cost: 1.7      Valid Accuracy: 0.31
# Epoch 22, CIFAR-10 Batch 4:  Cost: 1.99     Valid Accuracy: 0.32
# Epoch 22, CIFAR-10 Batch 5:  Cost: 1.86     Valid Accuracy: 0.325
# Epoch 23, CIFAR-10 Batch 1:  Cost: 1.89     Valid Accuracy: 0.338
# Epoch 23, CIFAR-10 Batch 2:  Cost: 1.92     Valid Accuracy: 0.334
# Epoch 23, CIFAR-10 Batch 3:  Cost: 1.6      Valid Accuracy: 0.345
# Epoch 23, CIFAR-10 Batch 4:  Cost: 1.87     Valid Accuracy: 0.35
# Epoch 23, CIFAR-10 Batch 5:  Cost: 1.82     Valid Accuracy: 0.351
# Epoch 24, CIFAR-10 Batch 1:  Cost: 1.87     Valid Accuracy: 0.36
# Epoch 24, CIFAR-10 Batch 2:  Cost: 1.85     Valid Accuracy: 0.36
# Epoch 24, CIFAR-10 Batch 3:  Cost: 1.56     Valid Accuracy: 0.364
# Epoch 24, CIFAR-10 Batch 4:  Cost: 1.79     Valid Accuracy: 0.365
# Epoch 24, CIFAR-10 Batch 5:  Cost: 1.8      Valid Accuracy: 0.362
# Epoch 25, CIFAR-10 Batch 1:  Cost: 1.85     Valid Accuracy: 0.373
# Epoch 25, CIFAR-10 Batch 2:  Cost: 1.82     Valid Accuracy: 0.373
# Epoch 25, CIFAR-10 Batch 3:  Cost: 1.56     Valid Accuracy: 0.377
# Epoch 25, CIFAR-10 Batch 4:  Cost: 1.74     Valid Accuracy: 0.381
# Epoch 25, CIFAR-10 Batch 5:  Cost: 1.77     Valid Accuracy: 0.38
# Epoch 26, CIFAR-10 Batch 1:  Cost: 1.81     Valid Accuracy: 0.381
# Epoch 26, CIFAR-10 Batch 2:  Cost: 1.8      Valid Accuracy: 0.382
# Epoch 26, CIFAR-10 Batch 3:  Cost: 1.55     Valid Accuracy: 0.389
# Epoch 26, CIFAR-10 Batch 4:  Cost: 1.7      Valid Accuracy: 0.386
# Epoch 26, CIFAR-10 Batch 5:  Cost: 1.76     Valid Accuracy: 0.389
# Epoch 27, CIFAR-10 Batch 1:  Cost: 1.78     Valid Accuracy: 0.386
# Epoch 27, CIFAR-10 Batch 2:  Cost: 1.8      Valid Accuracy: 0.386
# Epoch 27, CIFAR-10 Batch 3:  Cost: 1.55     Valid Accuracy: 0.391
# Epoch 27, CIFAR-10 Batch 4:  Cost: 1.67     Valid Accuracy: 0.393
# Epoch 27, CIFAR-10 Batch 5:  Cost: 1.75     Valid Accuracy: 0.393
# Epoch 28, CIFAR-10 Batch 1:  Cost: 1.78     Valid Accuracy: 0.395
# Epoch 28, CIFAR-10 Batch 2:  Cost: 1.78     Valid Accuracy: 0.393
# Epoch 28, CIFAR-10 Batch 3:  Cost: 1.54     Valid Accuracy: 0.399
# Epoch 28, CIFAR-10 Batch 4:  Cost: 1.65     Valid Accuracy: 0.398
# Epoch 28, CIFAR-10 Batch 5:  Cost: 1.72     Valid Accuracy: 0.396
# Epoch 29, CIFAR-10 Batch 1:  Cost: 1.78     Valid Accuracy: 0.4
# Epoch 29, CIFAR-10 Batch 2:  Cost: 1.77     Valid Accuracy: 0.396
# Epoch 29, CIFAR-10 Batch 3:  Cost: 1.55     Valid Accuracy: 0.399
# Epoch 29, CIFAR-10 Batch 4:  Cost: 1.62     Valid Accuracy: 0.401
# Epoch 29, CIFAR-10 Batch 5:  Cost: 1.71     Valid Accuracy: 0.398
# Epoch 30, CIFAR-10 Batch 1:  Cost: 1.77     Valid Accuracy: 0.4
# Epoch 30, CIFAR-10 Batch 2:  Cost: 1.77     Valid Accuracy: 0.398
# Epoch 30, CIFAR-10 Batch 3:  Cost: 1.54     Valid Accuracy: 0.4
# Epoch 30, CIFAR-10 Batch 4:  Cost: 1.59     Valid Accuracy: 0.404
# Epoch 30, CIFAR-10 Batch 5:  Cost: 1.69     Valid Accuracy: 0.4
# Epoch 31, CIFAR-10 Batch 1:  Cost: 1.76     Valid Accuracy: 0.405
# Epoch 31, CIFAR-10 Batch 2:  Cost: 1.75     Valid Accuracy: 0.4
# Epoch 31, CIFAR-10 Batch 3:  Cost: 1.54     Valid Accuracy: 0.403
# Epoch 31, CIFAR-10 Batch 4:  Cost: 1.59     Valid Accuracy: 0.406
# Epoch 31, CIFAR-10 Batch 5:  Cost: 1.68     Valid Accuracy: 0.405
# Epoch 32, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.408
# Epoch 32, CIFAR-10 Batch 2:  Cost: 1.74     Valid Accuracy: 0.404
# Epoch 32, CIFAR-10 Batch 3:  Cost: 1.53     Valid Accuracy: 0.407
# Epoch 32, CIFAR-10 Batch 4:  Cost: 1.57     Valid Accuracy: 0.413
# Epoch 32, CIFAR-10 Batch 5:  Cost: 1.68     Valid Accuracy: 0.406
# Epoch 33, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.411
# Epoch 33, CIFAR-10 Batch 2:  Cost: 1.74     Valid Accuracy: 0.407
# Epoch 33, CIFAR-10 Batch 3:  Cost: 1.52     Valid Accuracy: 0.411
# Epoch 33, CIFAR-10 Batch 4:  Cost: 1.56     Valid Accuracy: 0.416
# Epoch 33, CIFAR-10 Batch 5:  Cost: 1.67     Valid Accuracy: 0.41
# Epoch 34, CIFAR-10 Batch 1:  Cost: 1.74     Valid Accuracy: 0.417
# Epoch 34, CIFAR-10 Batch 2:  Cost: 1.71     Valid Accuracy: 0.406
# Epoch 34, CIFAR-10 Batch 3:  Cost: 1.51     Valid Accuracy: 0.414
# Epoch 34, CIFAR-10 Batch 4:  Cost: 1.55     Valid Accuracy: 0.418
# Epoch 34, CIFAR-10 Batch 5:  Cost: 1.66     Valid Accuracy: 0.414
# Epoch 35, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.422
# Epoch 35, CIFAR-10 Batch 2:  Cost: 1.71     Valid Accuracy: 0.413
# Epoch 35, CIFAR-10 Batch 3:  Cost: 1.51     Valid Accuracy: 0.415
# Epoch 35, CIFAR-10 Batch 4:  Cost: 1.54     Valid Accuracy: 0.418
# Epoch 35, CIFAR-10 Batch 5:  Cost: 1.65     Valid Accuracy: 0.418
# Epoch 36, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.422
# Epoch 36, CIFAR-10 Batch 2:  Cost: 1.69     Valid Accuracy: 0.414
# Epoch 36, CIFAR-10 Batch 3:  Cost: 1.49     Valid Accuracy: 0.419
# Epoch 36, CIFAR-10 Batch 4:  Cost: 1.53     Valid Accuracy: 0.42
# Epoch 36, CIFAR-10 Batch 5:  Cost: 1.65     Valid Accuracy: 0.416
# Epoch 37, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.422
# Epoch 37, CIFAR-10 Batch 2:  Cost: 1.66     Valid Accuracy: 0.417
# Epoch 37, CIFAR-10 Batch 3:  Cost: 1.48     Valid Accuracy: 0.422
# Epoch 37, CIFAR-10 Batch 4:  Cost: 1.53     Valid Accuracy: 0.423
# Epoch 37, CIFAR-10 Batch 5:  Cost: 1.64     Valid Accuracy: 0.422
# Epoch 38, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.422
# Epoch 38, CIFAR-10 Batch 2:  Cost: 1.65     Valid Accuracy: 0.415
# Epoch 38, CIFAR-10 Batch 3:  Cost: 1.47     Valid Accuracy: 0.422
# Epoch 38, CIFAR-10 Batch 4:  Cost: 1.51     Valid Accuracy: 0.426
# Epoch 38, CIFAR-10 Batch 5:  Cost: 1.64     Valid Accuracy: 0.424
# Epoch 39, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.425
# Epoch 39, CIFAR-10 Batch 2:  Cost: 1.63     Valid Accuracy: 0.419
# Epoch 39, CIFAR-10 Batch 3:  Cost: 1.47     Valid Accuracy: 0.426
# Epoch 39, CIFAR-10 Batch 4:  Cost: 1.51     Valid Accuracy: 0.43
# Epoch 39, CIFAR-10 Batch 5:  Cost: 1.64     Valid Accuracy: 0.429
# Epoch 40, CIFAR-10 Batch 1:  Cost: 1.74     Valid Accuracy: 0.424
# Epoch 40, CIFAR-10 Batch 2:  Cost: 1.63     Valid Accuracy: 0.423
# Epoch 40, CIFAR-10 Batch 3:  Cost: 1.46     Valid Accuracy: 0.427
# Epoch 40, CIFAR-10 Batch 4:  Cost: 1.5      Valid Accuracy: 0.43
# Epoch 40, CIFAR-10 Batch 5:  Cost: 1.63     Valid Accuracy: 0.429
# Epoch 41, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.427
# Epoch 41, CIFAR-10 Batch 2:  Cost: 1.62     Valid Accuracy: 0.427
# Epoch 41, CIFAR-10 Batch 3:  Cost: 1.45     Valid Accuracy: 0.43
# Epoch 41, CIFAR-10 Batch 4:  Cost: 1.5      Valid Accuracy: 0.434
# Epoch 41, CIFAR-10 Batch 5:  Cost: 1.62     Valid Accuracy: 0.433
# Epoch 42, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.429
# Epoch 42, CIFAR-10 Batch 2:  Cost: 1.61     Valid Accuracy: 0.427
# Epoch 42, CIFAR-10 Batch 3:  Cost: 1.45     Valid Accuracy: 0.431
# Epoch 42, CIFAR-10 Batch 4:  Cost: 1.5      Valid Accuracy: 0.437
# Epoch 42, CIFAR-10 Batch 5:  Cost: 1.61     Valid Accuracy: 0.429
# Epoch 43, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.436
# Epoch 43, CIFAR-10 Batch 2:  Cost: 1.61     Valid Accuracy: 0.429
# Epoch 43, CIFAR-10 Batch 3:  Cost: 1.45     Valid Accuracy: 0.428
# Epoch 43, CIFAR-10 Batch 4:  Cost: 1.5      Valid Accuracy: 0.436
# Epoch 43, CIFAR-10 Batch 5:  Cost: 1.59     Valid Accuracy: 0.432
# Epoch 44, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.432
# Epoch 44, CIFAR-10 Batch 2:  Cost: 1.63     Valid Accuracy: 0.438
# Epoch 44, CIFAR-10 Batch 3:  Cost: 1.43     Valid Accuracy: 0.434
# Epoch 44, CIFAR-10 Batch 4:  Cost: 1.48     Valid Accuracy: 0.44
# Epoch 44, CIFAR-10 Batch 5:  Cost: 1.57     Valid Accuracy: 0.438
# Epoch 45, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.442
# Epoch 45, CIFAR-10 Batch 2:  Cost: 1.61     Valid Accuracy: 0.437
# Epoch 45, CIFAR-10 Batch 3:  Cost: 1.42     Valid Accuracy: 0.44
# Epoch 45, CIFAR-10 Batch 4:  Cost: 1.44     Valid Accuracy: 0.442
# Epoch 45, CIFAR-10 Batch 5:  Cost: 1.58     Valid Accuracy: 0.443
# Epoch 46, CIFAR-10 Batch 1:  Cost: 1.73     Valid Accuracy: 0.446
# Epoch 46, CIFAR-10 Batch 2:  Cost: 1.6      Valid Accuracy: 0.446
# Epoch 46, CIFAR-10 Batch 3:  Cost: 1.42     Valid Accuracy: 0.447
# Epoch 46, CIFAR-10 Batch 4:  Cost: 1.43     Valid Accuracy: 0.445
# Epoch 46, CIFAR-10 Batch 5:  Cost: 1.57     Valid Accuracy: 0.447
# Epoch 47, CIFAR-10 Batch 1:  Cost: 1.7      Valid Accuracy: 0.447
# Epoch 47, CIFAR-10 Batch 2:  Cost: 1.58     Valid Accuracy: 0.444
# Epoch 47, CIFAR-10 Batch 3:  Cost: 1.4      Valid Accuracy: 0.449
# Epoch 47, CIFAR-10 Batch 4:  Cost: 1.4      Valid Accuracy: 0.453
# Epoch 47, CIFAR-10 Batch 5:  Cost: 1.57     Valid Accuracy: 0.449
# Epoch 48, CIFAR-10 Batch 1:  Cost: 1.69     Valid Accuracy: 0.451
# Epoch 48, CIFAR-10 Batch 2:  Cost: 1.57     Valid Accuracy: 0.444
# Epoch 48, CIFAR-10 Batch 3:  Cost: 1.39     Valid Accuracy: 0.451
# Epoch 48, CIFAR-10 Batch 4:  Cost: 1.4      Valid Accuracy: 0.454
# Epoch 48, CIFAR-10 Batch 5:  Cost: 1.58     Valid Accuracy: 0.446
# Epoch 49, CIFAR-10 Batch 1:  Cost: 1.67     Valid Accuracy: 0.453
# Epoch 49, CIFAR-10 Batch 2:  Cost: 1.56     Valid Accuracy: 0.451
# Epoch 49, CIFAR-10 Batch 3:  Cost: 1.38     Valid Accuracy: 0.455
# Epoch 49, CIFAR-10 Batch 4:  Cost: 1.4      Valid Accuracy: 0.458
# Epoch 49, CIFAR-10 Batch 5:  Cost: 1.56     Valid Accuracy: 0.451
# Epoch 50, CIFAR-10 Batch 1:  Cost: 1.65     Valid Accuracy: 0.455
# Epoch 50, CIFAR-10 Batch 2:  Cost: 1.53     Valid Accuracy: 0.452
# Epoch 50, CIFAR-10 Batch 3:  Cost: 1.36     Valid Accuracy: 0.455
# Epoch 50, CIFAR-10 Batch 4:  Cost: 1.39     Valid Accuracy: 0.457
# Epoch 50, CIFAR-10 Batch 5:  Cost: 1.56     Valid Accuracy: 0.458
# Epoch 51, CIFAR-10 Batch 1:  Cost: 1.64     Valid Accuracy: 0.454
# Epoch 51, CIFAR-10 Batch 2:  Cost: 1.53     Valid Accuracy: 0.454
# Epoch 51, CIFAR-10 Batch 3:  Cost: 1.36     Valid Accuracy: 0.455
# Epoch 51, CIFAR-10 Batch 4:  Cost: 1.39     Valid Accuracy: 0.458
# Epoch 51, CIFAR-10 Batch 5:  Cost: 1.56     Valid Accuracy: 0.46
# Epoch 52, CIFAR-10 Batch 1:  Cost: 1.63     Valid Accuracy: 0.458
# Epoch 52, CIFAR-10 Batch 2:  Cost: 1.51     Valid Accuracy: 0.456
# Epoch 52, CIFAR-10 Batch 3:  Cost: 1.34     Valid Accuracy: 0.459
# Epoch 52, CIFAR-10 Batch 4:  Cost: 1.38     Valid Accuracy: 0.459
# Epoch 52, CIFAR-10 Batch 5:  Cost: 1.55     Valid Accuracy: 0.458
# Epoch 53, CIFAR-10 Batch 1:  Cost: 1.62     Valid Accuracy: 0.458
# Epoch 53, CIFAR-10 Batch 2:  Cost: 1.5      Valid Accuracy: 0.456
# Epoch 53, CIFAR-10 Batch 3:  Cost: 1.34     Valid Accuracy: 0.461
# Epoch 53, CIFAR-10 Batch 4:  Cost: 1.37     Valid Accuracy: 0.46
# Epoch 53, CIFAR-10 Batch 5:  Cost: 1.54     Valid Accuracy: 0.458
# Epoch 54, CIFAR-10 Batch 1:  Cost: 1.61     Valid Accuracy: 0.459
# Epoch 54, CIFAR-10 Batch 2:  Cost: 1.48     Valid Accuracy: 0.458
# Epoch 54, CIFAR-10 Batch 3:  Cost: 1.33     Valid Accuracy: 0.464
# Epoch 54, CIFAR-10 Batch 4:  Cost: 1.36     Valid Accuracy: 0.466
# Epoch 54, CIFAR-10 Batch 5:  Cost: 1.53     Valid Accuracy: 0.457
# Epoch 55, CIFAR-10 Batch 1:  Cost: 1.6      Valid Accuracy: 0.464
# Epoch 55, CIFAR-10 Batch 2:  Cost: 1.47     Valid Accuracy: 0.459
# Epoch 55, CIFAR-10 Batch 3:  Cost: 1.32     Valid Accuracy: 0.464
# Epoch 55, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.465
# Epoch 55, CIFAR-10 Batch 5:  Cost: 1.53     Valid Accuracy: 0.46
# Epoch 56, CIFAR-10 Batch 1:  Cost: 1.59     Valid Accuracy: 0.465
# Epoch 56, CIFAR-10 Batch 2:  Cost: 1.46     Valid Accuracy: 0.462
# Epoch 56, CIFAR-10 Batch 3:  Cost: 1.32     Valid Accuracy: 0.465
# Epoch 56, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.467
# Epoch 56, CIFAR-10 Batch 5:  Cost: 1.54     Valid Accuracy: 0.461
# Epoch 57, CIFAR-10 Batch 1:  Cost: 1.58     Valid Accuracy: 0.466
# Epoch 57, CIFAR-10 Batch 2:  Cost: 1.45     Valid Accuracy: 0.466
# Epoch 57, CIFAR-10 Batch 3:  Cost: 1.31     Valid Accuracy: 0.465
# Epoch 57, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.468
# Epoch 57, CIFAR-10 Batch 5:  Cost: 1.53     Valid Accuracy: 0.466
# Epoch 58, CIFAR-10 Batch 1:  Cost: 1.58     Valid Accuracy: 0.467
# Epoch 58, CIFAR-10 Batch 2:  Cost: 1.44     Valid Accuracy: 0.466
# Epoch 58, CIFAR-10 Batch 3:  Cost: 1.3      Valid Accuracy: 0.468
# Epoch 58, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.472
# Epoch 58, CIFAR-10 Batch 5:  Cost: 1.52     Valid Accuracy: 0.466
# Epoch 59, CIFAR-10 Batch 1:  Cost: 1.57     Valid Accuracy: 0.473
# Epoch 59, CIFAR-10 Batch 2:  Cost: 1.43     Valid Accuracy: 0.472
# Epoch 59, CIFAR-10 Batch 3:  Cost: 1.29     Valid Accuracy: 0.47
# Epoch 59, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.476
# Epoch 59, CIFAR-10 Batch 5:  Cost: 1.52     Valid Accuracy: 0.471
# Epoch 60, CIFAR-10 Batch 1:  Cost: 1.56     Valid Accuracy: 0.472
# Epoch 60, CIFAR-10 Batch 2:  Cost: 1.42     Valid Accuracy: 0.475
# Epoch 60, CIFAR-10 Batch 3:  Cost: 1.29     Valid Accuracy: 0.469
# Epoch 60, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.475
# Epoch 60, CIFAR-10 Batch 5:  Cost: 1.5      Valid Accuracy: 0.472
# Epoch 61, CIFAR-10 Batch 1:  Cost: 1.55     Valid Accuracy: 0.473
# Epoch 61, CIFAR-10 Batch 2:  Cost: 1.4      Valid Accuracy: 0.474
# Epoch 61, CIFAR-10 Batch 3:  Cost: 1.29     Valid Accuracy: 0.471
# Epoch 61, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.474
# Epoch 61, CIFAR-10 Batch 5:  Cost: 1.49     Valid Accuracy: 0.475
# Epoch 62, CIFAR-10 Batch 1:  Cost: 1.55     Valid Accuracy: 0.475
# Epoch 62, CIFAR-10 Batch 2:  Cost: 1.39     Valid Accuracy: 0.476
# Epoch 62, CIFAR-10 Batch 3:  Cost: 1.28     Valid Accuracy: 0.472
# Epoch 62, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.479
# Epoch 62, CIFAR-10 Batch 5:  Cost: 1.49     Valid Accuracy: 0.478
# Epoch 63, CIFAR-10 Batch 1:  Cost: 1.53     Valid Accuracy: 0.477
# Epoch 63, CIFAR-10 Batch 2:  Cost: 1.39     Valid Accuracy: 0.472
# Epoch 63, CIFAR-10 Batch 3:  Cost: 1.27     Valid Accuracy: 0.474
# Epoch 63, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.48
# Epoch 63, CIFAR-10 Batch 5:  Cost: 1.47     Valid Accuracy: 0.477
# Epoch 64, CIFAR-10 Batch 1:  Cost: 1.53     Valid Accuracy: 0.479
# Epoch 64, CIFAR-10 Batch 2:  Cost: 1.37     Valid Accuracy: 0.476
# Epoch 64, CIFAR-10 Batch 3:  Cost: 1.25     Valid Accuracy: 0.477
# Epoch 64, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.48
# Epoch 64, CIFAR-10 Batch 5:  Cost: 1.47     Valid Accuracy: 0.479
# Epoch 65, CIFAR-10 Batch 1:  Cost: 1.52     Valid Accuracy: 0.478
# Epoch 65, CIFAR-10 Batch 2:  Cost: 1.36     Valid Accuracy: 0.479
# Epoch 65, CIFAR-10 Batch 3:  Cost: 1.24     Valid Accuracy: 0.477
# Epoch 65, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.482
# Epoch 65, CIFAR-10 Batch 5:  Cost: 1.46     Valid Accuracy: 0.477
# Epoch 66, CIFAR-10 Batch 1:  Cost: 1.52     Valid Accuracy: 0.481
# Epoch 66, CIFAR-10 Batch 2:  Cost: 1.34     Valid Accuracy: 0.482
# Epoch 66, CIFAR-10 Batch 3:  Cost: 1.22     Valid Accuracy: 0.483
# Epoch 66, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.483
# Epoch 66, CIFAR-10 Batch 5:  Cost: 1.45     Valid Accuracy: 0.478
# Epoch 67, CIFAR-10 Batch 1:  Cost: 1.53     Valid Accuracy: 0.483
# Epoch 67, CIFAR-10 Batch 2:  Cost: 1.33     Valid Accuracy: 0.483
# Epoch 67, CIFAR-10 Batch 3:  Cost: 1.21     Valid Accuracy: 0.487
# Epoch 67, CIFAR-10 Batch 4:  Cost: 1.37     Valid Accuracy: 0.488
# Epoch 67, CIFAR-10 Batch 5:  Cost: 1.44     Valid Accuracy: 0.48
# Epoch 68, CIFAR-10 Batch 1:  Cost: 1.54     Valid Accuracy: 0.492
# Epoch 68, CIFAR-10 Batch 2:  Cost: 1.31     Valid Accuracy: 0.484
# Epoch 68, CIFAR-10 Batch 3:  Cost: 1.2      Valid Accuracy: 0.488
# Epoch 68, CIFAR-10 Batch 4:  Cost: 1.36     Valid Accuracy: 0.488
# Epoch 68, CIFAR-10 Batch 5:  Cost: 1.43     Valid Accuracy: 0.485
# Epoch 69, CIFAR-10 Batch 1:  Cost: 1.53     Valid Accuracy: 0.49
# Epoch 69, CIFAR-10 Batch 2:  Cost: 1.32     Valid Accuracy: 0.486
# Epoch 69, CIFAR-10 Batch 3:  Cost: 1.19     Valid Accuracy: 0.491
# Epoch 69, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.492
# Epoch 69, CIFAR-10 Batch 5:  Cost: 1.41     Valid Accuracy: 0.489
# Epoch 70, CIFAR-10 Batch 1:  Cost: 1.51     Valid Accuracy: 0.489
# Epoch 70, CIFAR-10 Batch 2:  Cost: 1.31     Valid Accuracy: 0.489
# Epoch 70, CIFAR-10 Batch 3:  Cost: 1.16     Valid Accuracy: 0.492
# Epoch 70, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.494
# Epoch 70, CIFAR-10 Batch 5:  Cost: 1.38     Valid Accuracy: 0.488
# Epoch 71, CIFAR-10 Batch 1:  Cost: 1.49     Valid Accuracy: 0.493
# Epoch 71, CIFAR-10 Batch 2:  Cost: 1.3      Valid Accuracy: 0.493
# Epoch 71, CIFAR-10 Batch 3:  Cost: 1.15     Valid Accuracy: 0.498
# Epoch 71, CIFAR-10 Batch 4:  Cost: 1.36     Valid Accuracy: 0.493
# Epoch 71, CIFAR-10 Batch 5:  Cost: 1.37     Valid Accuracy: 0.494
# Epoch 72, CIFAR-10 Batch 1:  Cost: 1.47     Valid Accuracy: 0.495
# Epoch 72, CIFAR-10 Batch 2:  Cost: 1.27     Valid Accuracy: 0.495
# Epoch 72, CIFAR-10 Batch 3:  Cost: 1.11     Valid Accuracy: 0.497
# Epoch 72, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.494
# Epoch 72, CIFAR-10 Batch 5:  Cost: 1.35     Valid Accuracy: 0.493
# Epoch 73, CIFAR-10 Batch 1:  Cost: 1.45     Valid Accuracy: 0.5
# Epoch 73, CIFAR-10 Batch 2:  Cost: 1.26     Valid Accuracy: 0.497
# Epoch 73, CIFAR-10 Batch 3:  Cost: 1.11     Valid Accuracy: 0.5
# Epoch 73, CIFAR-10 Batch 4:  Cost: 1.35     Valid Accuracy: 0.499
# Epoch 73, CIFAR-10 Batch 5:  Cost: 1.34     Valid Accuracy: 0.497
# Epoch 74, CIFAR-10 Batch 1:  Cost: 1.44     Valid Accuracy: 0.502
# Epoch 74, CIFAR-10 Batch 2:  Cost: 1.24     Valid Accuracy: 0.502
# Epoch 74, CIFAR-10 Batch 3:  Cost: 1.09     Valid Accuracy: 0.502
# Epoch 74, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.504
# Epoch 74, CIFAR-10 Batch 5:  Cost: 1.33     Valid Accuracy: 0.5
# Epoch 75, CIFAR-10 Batch 1:  Cost: 1.41     Valid Accuracy: 0.508
# Epoch 75, CIFAR-10 Batch 2:  Cost: 1.22     Valid Accuracy: 0.507
# Epoch 75, CIFAR-10 Batch 3:  Cost: 1.08     Valid Accuracy: 0.507
# Epoch 75, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.504
# Epoch 75, CIFAR-10 Batch 5:  Cost: 1.32     Valid Accuracy: 0.505
# Epoch 76, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.507
# Epoch 76, CIFAR-10 Batch 2:  Cost: 1.19     Valid Accuracy: 0.506
# Epoch 76, CIFAR-10 Batch 3:  Cost: 1.07     Valid Accuracy: 0.51
# Epoch 76, CIFAR-10 Batch 4:  Cost: 1.31     Valid Accuracy: 0.51
# Epoch 76, CIFAR-10 Batch 5:  Cost: 1.31     Valid Accuracy: 0.504
# Epoch 77, CIFAR-10 Batch 1:  Cost: 1.4      Valid Accuracy: 0.511
# Epoch 77, CIFAR-10 Batch 2:  Cost: 1.19     Valid Accuracy: 0.51
# Epoch 77, CIFAR-10 Batch 3:  Cost: 1.07     Valid Accuracy: 0.513
# Epoch 77, CIFAR-10 Batch 4:  Cost: 1.31     Valid Accuracy: 0.511
# Epoch 77, CIFAR-10 Batch 5:  Cost: 1.29     Valid Accuracy: 0.507
# Epoch 78, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.511
# Epoch 78, CIFAR-10 Batch 2:  Cost: 1.18     Valid Accuracy: 0.511
# Epoch 78, CIFAR-10 Batch 3:  Cost: 1.07     Valid Accuracy: 0.513
# Epoch 78, CIFAR-10 Batch 4:  Cost: 1.3      Valid Accuracy: 0.514
# Epoch 78, CIFAR-10 Batch 5:  Cost: 1.3      Valid Accuracy: 0.511
# Epoch 79, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.513
# Epoch 79, CIFAR-10 Batch 2:  Cost: 1.17     Valid Accuracy: 0.513
# Epoch 79, CIFAR-10 Batch 3:  Cost: 1.06     Valid Accuracy: 0.515
# Epoch 79, CIFAR-10 Batch 4:  Cost: 1.3      Valid Accuracy: 0.515
# Epoch 79, CIFAR-10 Batch 5:  Cost: 1.27     Valid Accuracy: 0.514
# Epoch 80, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.516
# Epoch 80, CIFAR-10 Batch 2:  Cost: 1.15     Valid Accuracy: 0.518
# Epoch 80, CIFAR-10 Batch 3:  Cost: 1.06     Valid Accuracy: 0.513
# Epoch 80, CIFAR-10 Batch 4:  Cost: 1.29     Valid Accuracy: 0.516
# Epoch 80, CIFAR-10 Batch 5:  Cost: 1.26     Valid Accuracy: 0.518
# Epoch 81, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.517
# Epoch 81, CIFAR-10 Batch 2:  Cost: 1.15     Valid Accuracy: 0.518
# Epoch 81, CIFAR-10 Batch 3:  Cost: 1.05     Valid Accuracy: 0.517
# Epoch 81, CIFAR-10 Batch 4:  Cost: 1.28     Valid Accuracy: 0.52
# Epoch 81, CIFAR-10 Batch 5:  Cost: 1.25     Valid Accuracy: 0.515
# Epoch 82, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.519
# Epoch 82, CIFAR-10 Batch 2:  Cost: 1.13     Valid Accuracy: 0.52
# Epoch 82, CIFAR-10 Batch 3:  Cost: 1.05     Valid Accuracy: 0.517
# Epoch 82, CIFAR-10 Batch 4:  Cost: 1.28     Valid Accuracy: 0.52
# Epoch 82, CIFAR-10 Batch 5:  Cost: 1.24     Valid Accuracy: 0.517
# Epoch 83, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.517
# Epoch 83, CIFAR-10 Batch 2:  Cost: 1.13     Valid Accuracy: 0.521
# Epoch 83, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.512
# Epoch 83, CIFAR-10 Batch 4:  Cost: 1.27     Valid Accuracy: 0.519
# Epoch 83, CIFAR-10 Batch 5:  Cost: 1.24     Valid Accuracy: 0.519
# Epoch 84, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.52
# Epoch 84, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.52
# Epoch 84, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.515
# Epoch 84, CIFAR-10 Batch 4:  Cost: 1.26     Valid Accuracy: 0.525
# Epoch 84, CIFAR-10 Batch 5:  Cost: 1.23     Valid Accuracy: 0.518
# Epoch 85, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.519
# Epoch 85, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.523
# Epoch 85, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.519
# Epoch 85, CIFAR-10 Batch 4:  Cost: 1.26     Valid Accuracy: 0.522
# Epoch 85, CIFAR-10 Batch 5:  Cost: 1.22     Valid Accuracy: 0.52
# Epoch 86, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.524
# Epoch 86, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.524
# Epoch 86, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.518
# Epoch 86, CIFAR-10 Batch 4:  Cost: 1.26     Valid Accuracy: 0.525
# Epoch 86, CIFAR-10 Batch 5:  Cost: 1.22     Valid Accuracy: 0.52
# Epoch 87, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.523
# Epoch 87, CIFAR-10 Batch 2:  Cost: 1.1      Valid Accuracy: 0.522
# Epoch 87, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.518
# Epoch 87, CIFAR-10 Batch 4:  Cost: 1.25     Valid Accuracy: 0.527
# Epoch 87, CIFAR-10 Batch 5:  Cost: 1.21     Valid Accuracy: 0.52
# Epoch 88, CIFAR-10 Batch 1:  Cost: 1.36     Valid Accuracy: 0.523
# Epoch 88, CIFAR-10 Batch 2:  Cost: 1.09     Valid Accuracy: 0.527
# Epoch 88, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.519
# Epoch 88, CIFAR-10 Batch 4:  Cost: 1.23     Valid Accuracy: 0.525
# Epoch 88, CIFAR-10 Batch 5:  Cost: 1.21     Valid Accuracy: 0.523
# Epoch 89, CIFAR-10 Batch 1:  Cost: 1.36     Valid Accuracy: 0.524
# Epoch 89, CIFAR-10 Batch 2:  Cost: 1.08     Valid Accuracy: 0.525
# Epoch 89, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.52
# Epoch 89, CIFAR-10 Batch 4:  Cost: 1.24     Valid Accuracy: 0.529
# Epoch 89, CIFAR-10 Batch 5:  Cost: 1.2      Valid Accuracy: 0.526
# Epoch 90, CIFAR-10 Batch 1:  Cost: 1.36     Valid Accuracy: 0.526
# Epoch 90, CIFAR-10 Batch 2:  Cost: 1.08     Valid Accuracy: 0.526
# Epoch 90, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.523
# Epoch 90, CIFAR-10 Batch 4:  Cost: 1.22     Valid Accuracy: 0.531
# Epoch 90, CIFAR-10 Batch 5:  Cost: 1.19     Valid Accuracy: 0.527
# Epoch 91, CIFAR-10 Batch 1:  Cost: 1.36     Valid Accuracy: 0.525
# Epoch 91, CIFAR-10 Batch 2:  Cost: 1.08     Valid Accuracy: 0.53
# Epoch 91, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.524
# Epoch 91, CIFAR-10 Batch 4:  Cost: 1.21     Valid Accuracy: 0.533
# Epoch 91, CIFAR-10 Batch 5:  Cost: 1.18     Valid Accuracy: 0.528
# Epoch 92, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.524
# Epoch 92, CIFAR-10 Batch 2:  Cost: 1.07     Valid Accuracy: 0.529
# Epoch 92, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.527
# Epoch 92, CIFAR-10 Batch 4:  Cost: 1.2      Valid Accuracy: 0.53
# Epoch 92, CIFAR-10 Batch 5:  Cost: 1.18     Valid Accuracy: 0.531
# Epoch 93, CIFAR-10 Batch 1:  Cost: 1.35     Valid Accuracy: 0.528
# Epoch 93, CIFAR-10 Batch 2:  Cost: 1.08     Valid Accuracy: 0.533
# Epoch 93, CIFAR-10 Batch 3:  Cost: 1.01     Valid Accuracy: 0.526
# Epoch 93, CIFAR-10 Batch 4:  Cost: 1.21     Valid Accuracy: 0.534
# Epoch 93, CIFAR-10 Batch 5:  Cost: 1.18     Valid Accuracy: 0.532
# Epoch 94, CIFAR-10 Batch 1:  Cost: 1.36     Valid Accuracy: 0.53
# Epoch 94, CIFAR-10 Batch 2:  Cost: 1.06     Valid Accuracy: 0.532
# Epoch 94, CIFAR-10 Batch 3:  Cost: 1.01     Valid Accuracy: 0.528
# Epoch 94, CIFAR-10 Batch 4:  Cost: 1.19     Valid Accuracy: 0.534
# Epoch 94, CIFAR-10 Batch 5:  Cost: 1.17     Valid Accuracy: 0.53
# Epoch 95, CIFAR-10 Batch 1:  Cost: 1.34     Valid Accuracy: 0.527
# Epoch 95, CIFAR-10 Batch 2:  Cost: 1.07     Valid Accuracy: 0.532
# Epoch 95, CIFAR-10 Batch 3:  Cost: 1.0      Valid Accuracy: 0.529
# Epoch 95, CIFAR-10 Batch 4:  Cost: 1.19     Valid Accuracy: 0.534
# Epoch 95, CIFAR-10 Batch 5:  Cost: 1.16     Valid Accuracy: 0.53
# Epoch 96, CIFAR-10 Batch 1:  Cost: 1.35     Valid Accuracy: 0.533
# Epoch 96, CIFAR-10 Batch 2:  Cost: 1.05     Valid Accuracy: 0.534
# Epoch 96, CIFAR-10 Batch 3:  Cost: 0.996    Valid Accuracy: 0.533
# Epoch 96, CIFAR-10 Batch 4:  Cost: 1.18     Valid Accuracy: 0.536
# Epoch 96, CIFAR-10 Batch 5:  Cost: 1.15     Valid Accuracy: 0.535
# Epoch 97, CIFAR-10 Batch 1:  Cost: 1.35     Valid Accuracy: 0.533
# Epoch 97, CIFAR-10 Batch 2:  Cost: 1.04     Valid Accuracy: 0.535
# Epoch 97, CIFAR-10 Batch 3:  Cost: 0.992    Valid Accuracy: 0.532
# Epoch 97, CIFAR-10 Batch 4:  Cost: 1.18     Valid Accuracy: 0.538
# Epoch 97, CIFAR-10 Batch 5:  Cost: 1.14     Valid Accuracy: 0.536
# Epoch 98, CIFAR-10 Batch 1:  Cost: 1.35     Valid Accuracy: 0.533
# Epoch 98, CIFAR-10 Batch 2:  Cost: 1.05     Valid Accuracy: 0.537
# Epoch 98, CIFAR-10 Batch 3:  Cost: 0.99     Valid Accuracy: 0.533
# Epoch 98, CIFAR-10 Batch 4:  Cost: 1.17     Valid Accuracy: 0.539
# Epoch 98, CIFAR-10 Batch 5:  Cost: 1.13     Valid Accuracy: 0.537
# Epoch 99, CIFAR-10 Batch 1:  Cost: 1.35     Valid Accuracy: 0.538
# Epoch 99, CIFAR-10 Batch 2:  Cost: 1.04     Valid Accuracy: 0.539
# Epoch 99, CIFAR-10 Batch 3:  Cost: 0.988    Valid Accuracy: 0.535
# Epoch 99, CIFAR-10 Batch 4:  Cost: 1.16     Valid Accuracy: 0.539
# Epoch 99, CIFAR-10 Batch 5:  Cost: 1.14     Valid Accuracy: 0.538
# Epoch 100, CIFAR-10 Batch 1:  Cost: 1.34     Valid Accuracy: 0.537
# Epoch 100, CIFAR-10 Batch 2:  Cost: 1.04     Valid Accuracy: 0.54
# Epoch 100, CIFAR-10 Batch 3:  Cost: 0.99     Valid Accuracy: 0.536
# Epoch 100, CIFAR-10 Batch 4:  Cost: 1.15     Valid Accuracy: 0.539
# Epoch 100, CIFAR-10 Batch 5:  Cost: 1.13     Valid Accuracy: 0.537

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5443037974683544

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
